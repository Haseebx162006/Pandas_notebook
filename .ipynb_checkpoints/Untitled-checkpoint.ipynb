# %%
import pandas as pd 
import numpy as np

# %%
my_list=[1,2,3,4]

# %%
a=pd.Series(my_list)

# %%
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
my_characters=["a","b"]

# %%
b=pd.Series(my_characters)

# %%
print(b)
# Out:
# 0    a
# 1    b
# dtype: object

# %%
arr=np.array([10,20,30])

# %%
ay=pd.Series(arr)

# %% [raw]
# print(ay)

# %%
numbers=[1,2]

# %%
num=pd.Series(numbers,index=my_characters)

# %%
print(num)
# Out:
# a    1
# b    2
# dtype: int64

# %%
data={
    "A":[1,2,3,4],
    "B":["a","b","c","d"],
    "C":[3,4,5,6]
}
d= pd.DataFrame(data)

# %%
print(d)
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d
